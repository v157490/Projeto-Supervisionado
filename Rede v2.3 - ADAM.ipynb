# %%
from torch import nn
import torch
from torchvision import models
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torchvision.utils import make_grid

import numpy as np

import pickle
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
with open('dataset.pickle', 'rb') as handle:
    ds_file = pickle.load(handle)

# %%
ds_file.keys()
# Out:
# dict_keys(['treino', 'validacao', 'teste'])

# %%
len(ds_file['teste'])
# Out:
# 200

# %%
ds_file['treino']
# Out:
# ['cat.10.jpg',
#  'cat.10005.jpg',
#  'cat.10008.jpg',
#  'cat.10014.jpg',
#  'cat.10017.jpg',
#  'cat.10018.jpg',
#  'cat.10026.jpg',
#  'cat.10052.jpg',
#  'cat.10063.jpg',
#  'cat.10070.jpg',
#  'cat.10073.jpg',
#  'cat.10092.jpg',
#  'cat.10102.jpg',
#  'cat.10103.jpg',
#  'cat.10133.jpg',
#  'cat.10138.jpg',
#  'cat.1014.jpg',
#  'cat.10142.jpg',
#  'cat.10145.jpg',
#  'cat.10165.jpg',
#  'cat.10195.jpg',
#  'cat.10202.jpg',
#  'cat.10206.jpg',
#  'cat.1021.jpg',
#  'cat.10213.jpg',
#  'cat.10217.jpg',
#  'cat.10220.jpg',
#  'cat.10229.jpg',
#  'cat.10231.jpg',
#  'cat.10234.jpg',
#  'cat.10250.jpg',
#  'cat.10259.jpg',
#  'cat.1026.jpg',
#  'cat.10261.jpg',
#  'cat.10284.jpg',
#  'cat.1029.jpg',
#  'cat.10312.jpg',
#  'cat.10315.jpg',
#  'cat.10331.jpg',
#  'cat.10336.jpg',
#  'cat.1036.jpg',
#  'cat.10360.jpg',
#  'cat.10362.jpg',
#  'cat.10369.jpg',
#  'cat.10384.jpg',
#  'cat.10389.jpg',
#  'cat.1039.jpg',
#  'cat.10393.jpg',
#  'cat.10400.jpg',
#  'cat.10402.jpg',
#  'cat.10414.jpg',
#  'cat.10451.jpg',
#  'cat.1046.jpg',
#  'cat.10460.jpg',
#  'cat.10471.jpg',
#  'cat.10481.jpg',
#  'cat.10504.jpg',
#  'cat.10509.jpg',
#  'cat.10512.jpg',
#  'cat.10524.jpg',
#  'cat.10544.jpg',
#  'cat.10570.jpg',
#  'cat.10577.jpg',
#  'cat.10582.jpg',
#  'cat.10583.jpg',
#  'cat.10588.jpg',
#  'cat.10605.jpg',
#  'cat.10642.jpg',
#  'cat.10643.jpg',
#  'cat.10668.jpg',
#  'cat.10669.jpg',
#  'cat.1067.jpg',
#  'cat.10678.jpg',
#  'cat.10686.jpg',
#  'cat.10697.jpg',
#  'cat.10700.jpg',
#  'cat.10726.jpg',
#  'cat.10744.jpg',
#  'cat.10754.jpg',
#  'cat.10759.jpg',
#  'cat.10762.jpg',
#  'cat.10764.jpg',
#  'cat.10779.jpg',
#  'cat.10784.jpg',
#  'cat.10789.jpg',
#  'cat.1080.jpg',
#  'cat.10813.jpg',
#  'cat.10814.jpg',
#  'cat.10819.jpg',
#  'cat.1083.jpg',
#  'cat.10834.jpg',
#  'cat.10845.jpg',
#  'cat.10846.jpg',
#  'cat.10863.jpg',
#  'cat.10865.jpg',
#  'cat.10878.jpg',
#  'cat.10889.jpg',
#  'cat.10890.jpg',
#  'cat.109.jpg',
#  'cat.10906.jpg',
#  'cat.10907.jpg',
#  'cat.10919.jpg',
#  'cat.1092.jpg',
#  'cat.10929.jpg',
#  'cat.10938.jpg',
#  'cat.10945.jpg',
#  'cat.10960.jpg',
#  'cat.10965.jpg',
#  'cat.10967.jpg',
#  'cat.1098.jpg',
#  'cat.10984.jpg',
#  'cat.10986.jpg',
#  'cat.10989.jpg',
#  'cat.1099.jpg',
#  'cat.10997.jpg',
#  'cat.11000.jpg',
#  'cat.11014.jpg',
#  'cat.11028.jpg',
#  'cat.11032.jpg',
#  'cat.11034.jpg',
#  'cat.11036.jpg',
#  'cat.1104.jpg',
#  'cat.11045.jpg',
#  'cat.1105.jpg',
#  'cat.11059.jpg',
#  'cat.11062.jpg',
#  'cat.11069.jpg',
#  'cat.1107.jpg',
#  'cat.11073.jpg',
#  'cat.11083.jpg',
#  'cat.11090.jpg',
#  'cat.11097.jpg',
#  'cat.111.jpg',
#  'cat.11112.jpg',
#  'cat.11123.jpg',
#  'cat.11124.jpg',
#  'cat.11134.jpg',
#  'cat.11135.jpg',
#  'cat.11141.jpg',
#  'cat.11153.jpg',
#  'cat.11156.jpg',
#  'cat.11173.jpg',
#  'cat.11184.jpg',
#  'cat.11218.jpg',
#  'cat.1123.jpg',
#  'cat.11231.jpg',
#  'cat.11251.jpg',
#  'cat.11258.jpg',
#  'cat.11262.jpg',
#  'cat.11263.jpg',
#  'cat.11265.jpg',
#  'cat.11270.jpg',
#  'cat.11278.jpg',
#  'cat.11285.jpg',
#  'cat.11291.jpg',
#  'cat.11293.jpg',
#  'cat.113.jpg',
#  'cat.11307.jpg',
#  'cat.11309.jpg',
#  'cat.11313.jpg',
#  'cat.11323.jpg',
#  'cat.11344.jpg',
#  'cat.11352.jpg',
#  'cat.1136.jpg',
#  'cat.1137.jpg',
#  'cat.11377.jpg',
#  'cat.11384.jpg',
#  'cat.11389.jpg',
#  'cat.11394.jpg',
#  'cat.11396.jpg',
#  'cat.11399.jpg',
#  'cat.11413.jpg',
#  'cat.11445.jpg',
#  'cat.11462.jpg',
#  'cat.11465.jpg',
#  'cat.11468.jpg',
#  'cat.11488.jpg',
#  'cat.1149.jpg',
#  'cat.11506.jpg',
#  'cat.11507.jpg',
#  'cat.1160.jpg',
#  'cat.11611.jpg',
#  'cat.11623.jpg',
#  'cat.11627.jpg',
#  'cat.11638.jpg',
#  'cat.11646.jpg',
#  'cat.11648.jpg',
#  'cat.11656.jpg',
#  'cat.11661.jpg',
#  'cat.11667.jpg',
#  'cat.11683.jpg',
#  'cat.11702.jpg',
#  'cat.11714.jpg',
#  'cat.11715.jpg',
#  'cat.11745.jpg',
#  'cat.11753.jpg',
#  'cat.11758.jpg',
#  'cat.11768.jpg',
#  'cat.11789.jpg',
#  'cat.11810.jpg',
#  'cat.11842.jpg',
#  'cat.11851.jpg',
#  'cat.11852.jpg',
#  'cat.1188.jpg',
#  'cat.1189.jpg',
#  'cat.11890.jpg',
#  'cat.11924.jpg',
#  'cat.11934.jpg',
#  'cat.11940.jpg',
#  'cat.1195.jpg',
#  'cat.11979.jpg',
#  'cat.11985.jpg',
#  'cat.1200.jpg',
#  'cat.1201.jpg',
#  'cat.1202.jpg',
#  'cat.12035.jpg',
#  'cat.12037.jpg',
#  'cat.12046.jpg',
#  'cat.12074.jpg',
#  'cat.12077.jpg',
#  'cat.12110.jpg',
#  'cat.12112.jpg',
#  'cat.12115.jpg',
#  'cat.12118.jpg',
#  'cat.12133.jpg',
#  'cat.1214.jpg',
#  'cat.12179.jpg',
#  'cat.12187.jpg',
#  'cat.12194.jpg',
#  'cat.12203.jpg',
#  'cat.12205.jpg',
#  'cat.1221.jpg',
#  'cat.12218.jpg',
#  'cat.1222.jpg',
#  'cat.12224.jpg',
#  'cat.12233.jpg',
#  'cat.12240.jpg',
#  'cat.12245.jpg',
#  'cat.12261.jpg',
#  'cat.12274.jpg',
#  'cat.12299.jpg',
#  'cat.12306.jpg',
#  'cat.12309.jpg',
#  'cat.12322.jpg',
#  'cat.12327.jpg',
#  'cat.12339.jpg',
#  'cat.12376.jpg',
#  'cat.124.jpg',
#  'cat.12407.jpg',
#  'cat.1241.jpg',
#  'cat.12437.jpg',
#  'cat.12441.jpg',
#  'cat.12456.jpg',
#  'cat.12457.jpg',
#  'cat.12465.jpg',
#  'cat.12474.jpg',
#  'cat.12488.jpg',
#  'cat.12497.jpg',
#  'cat.1282.jpg',
#  'cat.1283.jpg',
#  'cat.1297.jpg',
#  'cat.1303.jpg',
#  'cat.1309.jpg',
#  'cat.1310.jpg',
#  'cat.1313.jpg',
#  'cat.1314.jpg',
#  'cat.1319.jpg',
#  'cat.1320.jpg',
#  'cat.1328.jpg',
#  'cat.1352.jpg',
#  'cat.1357.jpg',
#  'cat.1358.jpg',
#  'cat.1374.jpg',
#  'cat.1382.jpg',
#  'cat.1383.jpg',
#  'cat.1388.jpg',
#  'cat.1391.jpg',
#  'cat.140.jpg',
#  'cat.1419.jpg',
#  'cat.1427.jpg',
#  'cat.145.jpg',
#  'cat.146.jpg',
#  'cat.1462.jpg',
#  'cat.1472.jpg',
#  'cat.1478.jpg',
#  'cat.1500.jpg',
#  'cat.1509.jpg',
#  'cat.1511.jpg',
#  'cat.1515.jpg',
#  'cat.1521.jpg',
#  'cat.1533.jpg',
#  'cat.1539.jpg',
#  'cat.1544.jpg',
#  'cat.1552.jpg',
#  'cat.1558.jpg',
#  'cat.1601.jpg',
#  'cat.1606.jpg',
#  'cat.1611.jpg',
#  'cat.1613.jpg',
#  'cat.1615.jpg',
#  'cat.1620.jpg',
#  'cat.163.jpg',
#  'cat.1632.jpg',
#  'cat.1635.jpg',
#  'cat.1637.jpg',
#  'cat.1638.jpg',
#  'cat.1644.jpg',
#  'cat.1649.jpg',
#  'cat.1650.jpg',
#  'cat.1661.jpg',
#  'cat.1671.jpg',
#  'cat.1673.jpg',
#  'cat.1708.jpg',
#  'cat.1732.jpg',
#  'cat.1756.jpg',
#  'cat.177.jpg',
#  'cat.1794.jpg',
#  'cat.1796.jpg',
#  'cat.1809.jpg',
#  'cat.1813.jpg',
#  'cat.1815.jpg',
#  'cat.1817.jpg',
#  'cat.1835.jpg',
#  'cat.1857.jpg',
#  'cat.1859.jpg',
#  'cat.187.jpg',
#  'cat.1871.jpg',
#  'cat.1873.jpg',
#  'cat.1883.jpg',
#  'cat.1889.jpg',
#  'cat.1896.jpg',
#  'cat.1906.jpg',
#  'cat.1909.jpg',
#  'cat.1914.jpg',
#  'cat.194.jpg',
#  'cat.1941.jpg',
#  'cat.195.jpg',
#  'cat.1956.jpg',
#  'cat.196.jpg',
#  'cat.1976.jpg',
#  'cat.1983.jpg',
#  'cat.2001.jpg',
#  'cat.2002.jpg',
#  'cat.2004.jpg',
#  'cat.2011.jpg',
#  'cat.2012.jpg',
#  'cat.2013.jpg',
#  'cat.2034.jpg',
#  'cat.2038.jpg',
#  'cat.2040.jpg',
#  'cat.2041.jpg',
#  'cat.2048.jpg',
#  'cat.2051.jpg',
#  'cat.206.jpg',
#  'cat.2063.jpg',
#  'cat.2073.jpg',
#  'cat.2074.jpg',
#  'cat.2075.jpg',
#  'cat.2083.jpg',
#  'cat.2089.jpg',
#  'cat.2092.jpg',
#  'cat.2099.jpg',
#  'cat.2110.jpg',
#  'cat.2117.jpg',
#  'cat.2119.jpg',
#  'cat.212.jpg',
#  'cat.2125.jpg',
#  'cat.2128.jpg',
#  'cat.2146.jpg',
#  'cat.215.jpg',
#  'cat.2160.jpg',
#  'cat.2168.jpg',
#  'cat.2171.jpg',
#  'cat.2172.jpg',
#  'cat.218.jpg',
#  'cat.2183.jpg',
#  'cat.2197.jpg',
#  'cat.2205.jpg',
#  'cat.2207.jpg',
#  'cat.2228.jpg',
#  'cat.2230.jpg',
#  'cat.2232.jpg',
#  'cat.2233.jpg',
#  'cat.2241.jpg',
#  'cat.2251.jpg',
#  'cat.2253.jpg',
#  'cat.2276.jpg',
#  'cat.2301.jpg',
#  'cat.2303.jpg',
#  'cat.2308.jpg',
#  'cat.2316.jpg',
#  'cat.2332.jpg',
#  'cat.2341.jpg',
#  'cat.2342.jpg',
#  'cat.2345.jpg',
#  'cat.2353.jpg',
#  'cat.2356.jpg',
#  'cat.2359.jpg',
#  'cat.2360.jpg',
#  'cat.2361.jpg',
#  'cat.2364.jpg',
#  'cat.2365.jpg',
#  'cat.2366.jpg',
#  'cat.2375.jpg',
#  'cat.2376.jpg',
#  'cat.2382.jpg',
#  'cat.2384.jpg',
#  'cat.24.jpg',
#  'cat.2400.jpg',
#  'cat.2423.jpg',
#  'cat.2438.jpg',
#  'cat.2465.jpg',
#  'cat.2482.jpg',
#  'cat.2484.jpg',
#  'cat.249.jpg',
#  'cat.2494.jpg',
#  'cat.2499.jpg',
#  'cat.2522.jpg',
#  'cat.2537.jpg',
#  'cat.2553.jpg',
#  'cat.2567.jpg',
#  'cat.2577.jpg',
#  'cat.2579.jpg',
#  'cat.2591.jpg',
#  'cat.2610.jpg',
#  'cat.2619.jpg',
#  'cat.2638.jpg',
#  'cat.2675.jpg',
#  'cat.2692.jpg',
#  'cat.2703.jpg',
#  'cat.2720.jpg',
#  'cat.2730.jpg',
#  'cat.2739.jpg',
#  'cat.2760.jpg',
#  'cat.2786.jpg',
#  'cat.2787.jpg',
#  'cat.2800.jpg',
#  'cat.282.jpg',
#  'cat.2824.jpg',
#  'cat.2827.jpg',
#  'cat.2829.jpg',
#  'cat.2836.jpg',
#  'cat.284.jpg',
#  'cat.2884.jpg',
#  'cat.2907.jpg',
#  'cat.2917.jpg',
#  'cat.2923.jpg',
#  'cat.2932.jpg',
#  'cat.2933.jpg',
#  'cat.2950.jpg',
#  'cat.2958.jpg',
#  'cat.297.jpg',
#  'cat.2980.jpg',
#  'cat.2983.jpg',
#  'cat.2985.jpg',
#  'cat.2995.jpg',
#  'cat.3000.jpg',
#  'cat.3007.jpg',
#  'cat.3035.jpg',
#  'cat.3039.jpg',
#  'cat.3045.jpg',
#  'cat.3046.jpg',
#  'cat.3059.jpg',
#  'cat.307.jpg',
#  'cat.3071.jpg',
#  'cat.3073.jpg',
#  'cat.312.jpg',
#  'cat.3126.jpg',
#  'cat.3137.jpg',
#  'cat.3138.jpg',
#  'cat.3146.jpg',
#  'cat.3158.jpg',
#  'cat.3160.jpg',
#  'cat.3172.jpg',
#  'cat.3175.jpg',
#  'cat.3183.jpg',
#  'cat.3184.jpg',
#  'cat.3188.jpg',
#  'cat.3201.jpg',
#  'cat.3203.jpg',
#  'cat.3237.jpg',
#  'cat.3243.jpg',
#  'cat.3251.jpg',
#  'cat.3257.jpg',
#  'cat.3273.jpg',
#  'cat.3275.jpg',
#  'cat.328.jpg',
#  'cat.3311.jpg',
#  'cat.3312.jpg',
#  'cat.3319.jpg',
#  'cat.3334.jpg',
#  'cat.3343.jpg',
#  'cat.3350.jpg',
#  'cat.3351.jpg',
#  'cat.3356.jpg',
#  'cat.3365.jpg',
#  'cat.3390.jpg',
#  'cat.340.jpg',
#  'cat.3415.jpg',
#  'cat.3432.jpg',
#  'cat.3459.jpg',
#  'cat.346.jpg',
#  'cat.3463.jpg',
#  'cat.3487.jpg',
#  'cat.3498.jpg',
#  'cat.3511.jpg',
#  'cat.3525.jpg',
#  'cat.3532.jpg',
#  'cat.3538.jpg',
#  'cat.3553.jpg',
#  'cat.3579.jpg',
#  'cat.3600.jpg',
#  'cat.3611.jpg',
#  'cat.3617.jpg',
#  'cat.3628.jpg',
#  'cat.3633.jpg',
#  'cat.3644.jpg',
#  'cat.3647.jpg',
#  'cat.3652.jpg',
#  'cat.367.jpg',
#  'cat.3671.jpg',
#  'cat.3674.jpg',
#  'cat.3675.jpg',
#  'cat.3678.jpg',
#  'cat.3681.jpg',
#  'cat.3690.jpg',
#  'cat.3695.jpg',
#  'cat.3706.jpg',
#  'cat.372.jpg',
#  'cat.3730.jpg',
#  'cat.3754.jpg',
#  'cat.3758.jpg',
#  'cat.3760.jpg',
#  'cat.3762.jpg',
#  'cat.3774.jpg',
#  'cat.3826.jpg',
#  'cat.3827.jpg',
#  'cat.385.jpg',
#  'cat.3858.jpg',
#  'cat.3862.jpg',
#  'cat.3882.jpg',
#  'cat.3889.jpg',
#  'cat.3891.jpg',
#  'cat.3895.jpg',
#  'cat.390.jpg',
#  'cat.3900.jpg',
#  'cat.3904.jpg',
#  'cat.3930.jpg',
#  'cat.3938.jpg',
#  'cat.3942.jpg',
#  'cat.3948.jpg',
#  'cat.3953.jpg',
#  'cat.3973.jpg',
#  'cat.3980.jpg',
#  'cat.4001.jpg',
#  'cat.4003.jpg',
#  'cat.4026.jpg',
#  'cat.4029.jpg',
#  'cat.4034.jpg',
#  'cat.4038.jpg',
#  'cat.4040.jpg',
#  'cat.4044.jpg',
#  'cat.4046.jpg',
#  'cat.405.jpg',
#  'cat.4050.jpg',
#  'cat.4056.jpg',
#  'cat.4058.jpg',
#  'cat.407.jpg',
#  'cat.4078.jpg',
#  'cat.4082.jpg',
#  'cat.4089.jpg',
#  'cat.4097.jpg',
#  'cat.4106.jpg',
#  'cat.4118.jpg',
#  'cat.4122.jpg',
#  'cat.4148.jpg',
#  'cat.4169.jpg',
#  'cat.4187.jpg',
#  'cat.4198.jpg',
#  'cat.4206.jpg',
#  'cat.4218.jpg',
#  'cat.4237.jpg',
#  'cat.4240.jpg',
#  'cat.4245.jpg',
#  'cat.4254.jpg',
#  'cat.4259.jpg',
#  'cat.4271.jpg',
#  'cat.4278.jpg',
#  'cat.4310.jpg',
#  'cat.4313.jpg',
#  'cat.4327.jpg',
#  'cat.4330.jpg',
#  'cat.4338.jpg',
#  'cat.4343.jpg',
#  'cat.435.jpg',
#  'cat.4363.jpg',
#  'cat.4365.jpg',
#  'cat.4371.jpg',
#  'cat.4387.jpg',
#  'cat.4393.jpg',
#  'cat.4398.jpg',
#  'cat.4425.jpg',
#  'cat.443.jpg',
#  'cat.4431.jpg',
#  'cat.4442.jpg',
#  'cat.4459.jpg',
#  'cat.4469.jpg',
#  'cat.4475.jpg',
#  'cat.4480.jpg',
#  'cat.45.jpg',
#  'cat.4504.jpg',
#  'cat.4521.jpg',
#  'cat.4543.jpg',
#  'cat.4551.jpg',
#  'cat.4566.jpg',
#  'cat.4567.jpg',
#  'cat.4583.jpg',
#  'cat.4591.jpg',
#  'cat.4597.jpg',
#  'cat.460.jpg',
#  'cat.4613.jpg',
#  'cat.4622.jpg',
#  'cat.4625.jpg',
#  'cat.4632.jpg',
#  'cat.4636.jpg',
#  'cat.4638.jpg',
#  'cat.4640.jpg',
#  'cat.4647.jpg',
#  'cat.4652.jpg',
#  'cat.4653.jpg',
#  'cat.4659.jpg',
#  'cat.4669.jpg',
#  'cat.4670.jpg',
#  'cat.4691.jpg',
#  'cat.4698.jpg',
#  'cat.4709.jpg',
#  'cat.4710.jpg',
#  'cat.4731.jpg',
#  'cat.4742.jpg',
#  'cat.4745.jpg',
#  'cat.4751.jpg',
#  'cat.477.jpg',
#  'cat.4770.jpg',
#  'cat.4783.jpg',
#  'cat.4789.jpg',
#  'cat.479.jpg',
#  'cat.48.jpg',
#  'cat.480.jpg',
#  'cat.4802.jpg',
#  'cat.4812.jpg',
#  'cat.4814.jpg',
#  'cat.4815.jpg',
#  'cat.4826.jpg',
#  'cat.4841.jpg',
#  'cat.4842.jpg',
#  'cat.4857.jpg',
#  'cat.4859.jpg',
#  'cat.4865.jpg',
#  'cat.4871.jpg',
#  'cat.4884.jpg',
#  'cat.489.jpg',
#  'cat.4896.jpg',
#  'cat.4901.jpg',
#  'cat.4902.jpg',
#  'cat.4914.jpg',
#  'cat.4918.jpg',
#  'cat.4951.jpg',
#  'cat.4965.jpg',
#  'cat.4977.jpg',
#  'cat.499.jpg',
#  'cat.5007.jpg',
#  'cat.502.jpg',
#  'cat.5023.jpg',
#  'cat.5032.jpg',
#  'cat.5040.jpg',
#  'cat.505.jpg',
#  'cat.5054.jpg',
#  'cat.5059.jpg',
#  'cat.5082.jpg',
#  'cat.5090.jpg',
#  'cat.5094.jpg',
#  'cat.5108.jpg',
#  'cat.5122.jpg',
#  'cat.5132.jpg',
#  'cat.515.jpg',
#  'cat.5150.jpg',
#  'cat.517.jpg',
#  'cat.5198.jpg',
#  'cat.5206.jpg',
#  'cat.5220.jpg',
#  'cat.5246.jpg',
#  'cat.5255.jpg',
#  'cat.5265.jpg',
#  'cat.5270.jpg',
#  'cat.5281.jpg',
#  'cat.5299.jpg',
#  'cat.5327.jpg',
#  'cat.5328.jpg',
#  'cat.5362.jpg',
#  'cat.5379.jpg',
#  'cat.538.jpg',
#  'cat.5393.jpg',
#  'cat.5397.jpg',
#  'cat.5407.jpg',
#  'cat.5408.jpg',
#  'cat.5417.jpg',
#  'cat.5423.jpg',
#  'cat.5432.jpg',
#  'cat.5438.jpg',
#  'cat.5451.jpg',
#  'cat.5454.jpg',
#  'cat.5455.jpg',
#  'cat.546.jpg',
#  'cat.5465.jpg',
#  'cat.5466.jpg',
#  'cat.5473.jpg',
#  'cat.5492.jpg',
#  'cat.5495.jpg',
#  'cat.5496.jpg',
#  'cat.5497.jpg',
#  'cat.5546.jpg',
#  'cat.555.jpg',
#  'cat.5554.jpg',
#  'cat.5599.jpg',
#  'cat.5610.jpg',
#  'cat.5617.jpg',
#  'cat.5627.jpg',
#  'cat.5638.jpg',
#  'cat.5647.jpg',
#  'cat.5653.jpg',
#  'cat.566.jpg',
#  'cat.5679.jpg',
#  'cat.5696.jpg',
#  'cat.5700.jpg',
#  'cat.5721.jpg',
#  'cat.5730.jpg',
#  'cat.5738.jpg',
#  'cat.5740.jpg',
#  'cat.5745.jpg',
#  'cat.5747.jpg',
#  'cat.5764.jpg',
#  'cat.5768.jpg',
#  'cat.5776.jpg',
#  'cat.5779.jpg',
#  'cat.5781.jpg',
#  'cat.5788.jpg',
#  'cat.5791.jpg',
#  'cat.5795.jpg',
#  'cat.5806.jpg',
#  'cat.5811.jpg',
#  'cat.5817.jpg',
#  'cat.582.jpg',
#  'cat.5835.jpg',
#  'cat.5838.jpg',
#  'cat.5844.jpg',
#  'cat.585.jpg',
#  'cat.5866.jpg',
#  'cat.5893.jpg',
#  'cat.5895.jpg',
#  'cat.5904.jpg',
#  'cat.5932.jpg',
#  'cat.5939.jpg',
#  'cat.5944.jpg',
#  'cat.5945.jpg',
#  'cat.597.jpg',
#  'cat.5972.jpg',
#  'cat.5990.jpg',
#  'cat.6001.jpg',
#  'cat.6010.jpg',
#  'cat.6027.jpg',
#  'cat.6028.jpg',
#  'cat.6045.jpg',
#  'cat.6049.jpg',
#  'cat.6053.jpg',
#  'cat.6054.jpg',
#  'cat.6055.jpg',
#  'cat.6063.jpg',
#  'cat.6072.jpg',
#  'cat.6076.jpg',
#  'cat.609.jpg',
#  'cat.610.jpg',
#  'cat.6104.jpg',
#  'cat.611.jpg',
#  'cat.6129.jpg',
#  'cat.613.jpg',
#  'cat.6131.jpg',
#  'cat.6150.jpg',
#  'cat.617.jpg',
#  'cat.6203.jpg',
#  'cat.6209.jpg',
#  'cat.6215.jpg',
#  'cat.6220.jpg',
#  'cat.6255.jpg',
#  'cat.6257.jpg',
#  'cat.626.jpg',
#  'cat.6263.jpg',
#  'cat.6274.jpg',
#  'cat.6275.jpg',
#  'cat.6284.jpg',
#  'cat.6293.jpg',
#  'cat.6299.jpg',
#  'cat.6321.jpg',
#  'cat.6328.jpg',
#  'cat.6336.jpg',
#  'cat.6355.jpg',
#  'cat.6365.jpg',
#  'cat.6372.jpg',
#  'cat.6380.jpg',
#  'cat.6384.jpg',
#  'cat.6399.jpg',
#  'cat.6407.jpg',
#  'cat.6416.jpg',
#  'cat.6417.jpg',
#  'cat.6418.jpg',
#  'cat.6427.jpg',
#  'cat.6432.jpg',
#  'cat.6433.jpg',
#  'cat.645.jpg',
#  'cat.6455.jpg',
#  'cat.6459.jpg',
#  'cat.6462.jpg',
#  'cat.6474.jpg',
#  'cat.6478.jpg',
#  'cat.648.jpg',
#  'cat.6493.jpg',
#  'cat.6501.jpg',
#  'cat.6517.jpg',
#  'cat.6526.jpg',
#  'cat.6531.jpg',
#  'cat.6532.jpg',
#  'cat.6545.jpg',
#  'cat.6565.jpg',
#  'cat.6568.jpg',
#  'cat.657.jpg',
#  'cat.6571.jpg',
#  'cat.6573.jpg',
#  'cat.6578.jpg',
#  'cat.6582.jpg',
#  'cat.6583.jpg',
#  'cat.6590.jpg',
#  'cat.6595.jpg',
#  'cat.66.jpg',
#  'cat.6601.jpg',
#  'cat.6602.jpg',
#  'cat.661.jpg',
#  'cat.6616.jpg',
#  'cat.6625.jpg',
#  'cat.6643.jpg',
#  'cat.6646.jpg',
#  'cat.6676.jpg',
#  'cat.6683.jpg',
#  'cat.6684.jpg',
#  'cat.6693.jpg',
#  'cat.6743.jpg',
#  'cat.6759.jpg',
#  'cat.6766.jpg',
#  'cat.6779.jpg',
#  'cat.6782.jpg',
#  'cat.679.jpg',
#  'cat.6809.jpg',
#  'cat.6815.jpg',
#  'cat.6818.jpg',
#  'cat.6825.jpg',
#  'cat.6831.jpg',
#  'cat.6843.jpg',
#  'cat.6853.jpg',
#  'cat.686.jpg',
#  'cat.6877.jpg',
#  'cat.6889.jpg',
#  'cat.6892.jpg',
#  'cat.6898.jpg',
#  'cat.6912.jpg',
#  'cat.693.jpg',
#  'cat.6932.jpg',
#  'cat.6945.jpg',
#  'cat.6964.jpg',
#  'cat.699.jpg',
#  'cat.6990.jpg',
#  'cat.700.jpg',
#  'cat.7029.jpg',
#  'cat.7063.jpg',
#  'cat.707.jpg',
#  'cat.7075.jpg',
#  'cat.7089.jpg',
#  'cat.7102.jpg',
#  'cat.7114.jpg',
#  'cat.7129.jpg',
#  'cat.7131.jpg',
#  'cat.7133.jpg',
#  'cat.7134.jpg',
#  'cat.7142.jpg',
#  'cat.716.jpg',
#  'cat.7193.jpg',
#  'cat.7201.jpg',
#  'cat.7212.jpg',
#  'cat.7220.jpg',
#  'cat.7221.jpg',
#  'cat.7252.jpg',
#  'cat.7268.jpg',
#  'cat.7273.jpg',
#  'cat.7279.jpg',
#  'cat.728.jpg',
#  'cat.7287.jpg',
#  'cat.7291.jpg',
#  'cat.73.jpg',
#  'cat.7302.jpg',
#  'cat.7315.jpg',
#  'cat.7325.jpg',
#  'cat.7364.jpg',
#  'cat.737.jpg',
#  'cat.7383.jpg',
#  'cat.7389.jpg',
#  'cat.7410.jpg',
#  'cat.7415.jpg',
#  'cat.7419.jpg',
#  'cat.742.jpg',
#  'cat.7441.jpg',
#  'cat.7448.jpg',
#  'cat.7449.jpg',
#  'cat.7452.jpg',
#  'cat.7457.jpg',
#  'cat.7458.jpg',
#  'cat.746.jpg',
#  'cat.7464.jpg',
#  'cat.7470.jpg',
#  'cat.7484.jpg',
#  'cat.7486.jpg',
#  'cat.7509.jpg',
#  'cat.7510.jpg',
#  'cat.7511.jpg',
#  'cat.7526.jpg',
#  'cat.7527.jpg',
#  'cat.7535.jpg',
#  'cat.7536.jpg',
#  'cat.754.jpg',
#  'cat.7546.jpg',
#  'cat.7559.jpg',
#  'cat.7565.jpg',
#  'cat.7569.jpg',
#  'cat.7574.jpg',
#  'cat.7575.jpg',
#  'cat.7576.jpg',
#  'cat.7580.jpg',
#  'cat.7589.jpg',
#  'cat.7613.jpg',
#  'cat.7617.jpg',
#  'cat.7618.jpg',
#  'cat.763.jpg',
#  'cat.7639.jpg',
#  'cat.7645.jpg',
#  'cat.7647.jpg',
#  'cat.7651.jpg',
#  'cat.7654.jpg',
#  'cat.7658.jpg',
#  'cat.7669.jpg',
#  'cat.7670.jpg',
#  'cat.7673.jpg',
#  'cat.7676.jpg',
#  'cat.7704.jpg',
#  'cat.7722.jpg',
#  'cat.7735.jpg',
#  'cat.7751.jpg',
#  'cat.776.jpg',
#  'cat.779.jpg',
#  'cat.7808.jpg',
#  'cat.7810.jpg',
#  'cat.7813.jpg',
#  'cat.7830.jpg',
#  'cat.7840.jpg',
#  'cat.7842.jpg',
#  'cat.7846.jpg',
#  'cat.7856.jpg',
#  'cat.7858.jpg',
#  'cat.7868.jpg',
#  'cat.7888.jpg',
#  'cat.7889.jpg',
#  'cat.7898.jpg',
#  'cat.7899.jpg',
#  'cat.7905.jpg',
#  'cat.7909.jpg',
#  'cat.7932.jpg',
#  'cat.7933.jpg',
#  'cat.7936.jpg',
#  'cat.7946.jpg',
#  'cat.7954.jpg',
#  'cat.796.jpg',
#  'cat.7995.jpg',
#  'cat.8018.jpg',
#  'cat.8026.jpg',
#  'cat.8035.jpg',
#  'cat.8037.jpg',
#  'cat.8044.jpg',
#  'cat.8073.jpg',
#  'cat.8075.jpg',
#  'cat.8095.jpg',
#  'cat.8096.jpg',
#  'cat.8098.jpg',
#  'cat.8099.jpg',
#  'cat.8108.jpg',
#  'cat.8122.jpg',
#  ...]

# %% [markdown]
# ### Dados

# %%
class CDdataset(Dataset):
    
    tfms = transforms.Compose([
        transforms.RandomAffine(degrees=(-90,90), translate=(0, 0.15), scale=(0.9, 1.1)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
    
    def __init__(self, x):
        self.x = x.copy()
        np.random.shuffle(self.x)
        
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, i):
        arq = self.x[i] 
        folder = '../Cats and dogs/data/cats/' if 'cat' in arq else '../Cats and dogs/data/dogs/'
        label = 1 if 'cat' in arq else 0
        imagem = Image.open(folder+arq).resize(2*(256,))
        return self.tfms(imagem), torch.tensor(label)

# %%
ds_treino = CDdataset(ds_file['treino'])
ds_val = CDdataset(ds_file['validacao'])
ds_teste = CDdataset(ds_file['teste'])

# %%
imagem, label = ds_treino[0]
imagem.numpy().transpose(1,2,0).dtype
# Out:
# dtype('float32')

# %%
fig,axes = plt.subplots(nrows=3,ncols=3, figsize=(10,10))

for i,ax in enumerate(axes.flatten()):
    imagem, label = ds_treino[i]
    ax.imshow(imagem.numpy().transpose(1,2,0))
    #ax.set_title(label)
    ax.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
dl_treino = DataLoader(ds_treino, batch_size=32, shuffle=True)
dl_val = DataLoader(ds_val, batch_size=16)

# %%
t_x, t_y = next(iter(dl_treino))

# %%
t_x.shape, t_y.shape
# Out:
# (torch.Size([32, 3, 256, 256]), torch.Size([32]))

# %% [markdown]
# ### Rede

# %%
class Modelo(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.resnet = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:-2])
        self.conv1 = nn.Conv2d(in_channels=512,out_channels=256, kernel_size=(4,4))
        self.conv2 = nn.Conv2d(in_channels=256,out_channels=1, kernel_size=(5,5))
        self.conv3 = nn.Conv2d(in_channels=1, out_channels=1, kernel_size=(1,1))
        
        for params in self.resnet.parameters():
            params.requires_grad = False
        
    def forward(self, x):
        x = self.resnet(x)
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        
        return x.squeeze()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-97b0e526a7ce> in <module>()
# ----> 1 class Modelo(nn.Module):
#       2
#       3     def __init__(self):
#       4         super().__init__()
#       5         self.resnet = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:-2])
#
# NameError: name 'nn' is not defined

# %%
modelo = Modelo()
modelo.to(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-db382cbdad96> in <module>()
# ----> 1 modelo = Modelo()
#       2 modelo.to(device)
#
# NameError: name 'Modelo' is not defined

# %%
modelo(t_x.to(device)).shape
# Out:
# torch.Size([32])

# %% [markdown]
# ### Loss, accuracy & optim

# %%
loss = nn.BCEWithLogitsLoss() 
optimizer = torch.optim.Adam(modelo.parameters(), lr=1e-3)

# %%
def accuracy(output, label, theta=0.5):
    p_out = torch.sigmoid(output) > theta
    return (p_out.float() == label.float()).float().mean()

# %%
best_acc = 0.5

# %%
epoch = 10
val_acc = []
val_cost = []
train_cost = []


for i in range(epoch):
    modelo.train()
    
    for t_x, t_y in dl_treino: 
        out = modelo(t_x.to(device))
        optimizer.zero_grad()
        cost = loss(out, t_y.float().to(device))
        cost.backward()
        optimizer.step()
        train_cost.append(cost.to('cpu').detach().numpy())
        
    modelo.eval()
    val_custo = 0
    acc = 0
    
    for v_x, v_y in dl_val:
        val_out = modelo(v_x.to(device))
        val_custo += loss(val_out, v_y.float().to(device)).to('cpu').detach().numpy()
        acc += accuracy(val_out.to('cpu'), v_y).numpy()
        
    val_acc.append(acc/len(dl_val))
    val_cost.append(val_custo/len(dl_val))
    
    if val_acc[-1] > best_acc:
        best_acc = val_acc[-1]
        torch.save(modelo.state_dict(), 'CatDog.pt')
        print('novo best_acc')
        
    print(f'Epoca {i+1}: \n Acuracia Validacao: {val_acc[-1]}\n Custo Validacao: {val_cost[-1]}\n')
# Out:
# novo best_acc
# Epoca 1:
#  Acuracia Validacao: 0.8894230769230769
#  Custo Validacao: 0.2770707498376186
#
# novo best_acc
# Epoca 2:
#  Acuracia Validacao: 0.9134615384615384
#  Custo Validacao: 0.2522904688778978
#
# Epoca 3:
#  Acuracia Validacao: 0.8846153846153846
#  Custo Validacao: 0.23590216212547743
#
# Epoca 4:
#  Acuracia Validacao: 0.8942307692307693
#  Custo Validacao: 0.3938121600792958
#
# novo best_acc
# Epoca 5:
#  Acuracia Validacao: 0.9615384615384616
#  Custo Validacao: 0.13523953723219725
#
# Epoca 6:
#  Acuracia Validacao: 0.9230769230769231
#  Custo Validacao: 0.18700657398081744
#
# Epoca 7:
#  Acuracia Validacao: 0.9326923076923077
#  Custo Validacao: 0.27492573456122327
#
# Epoca 8:
#  Acuracia Validacao: 0.9471153846153846
#  Custo Validacao: 0.13878404495951074
#
# Epoca 9:
#  Acuracia Validacao: 0.9182692307692307
#  Custo Validacao: 0.21145597042945716
#
# Epoca 10:
#  Acuracia Validacao: 0.9567307692307693
#  Custo Validacao: 0.22756647361585727

# %%
plt.plot(np.arange(len(train_cost)), train_cost)
plt.plot(np.arange(len(val_cost)), val_cost)

# %%
fig, ax = plt.subplots()
ax.plot(np.arange(len(train_cost)), train_cost)
ax.set_title('Custo treino')
ax.set_xlabel('Iterações')
ax.set_ylabel('Custo')
plt.savefig('CustoTreinoADAMPytorch')

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize=(10,6))
fig.subplots_adjust(wspace=0.5)
ax1.plot(np.arange(len(val_cost)), val_cost)
ax1.set_title('Custo')
ax1.grid('on')
ax1.set_xlabel('Epocas')
ax1.set_ylabel('Custo')
ax2.plot(np.arange(len(val_acc)), val_acc)
ax2.set_title('Acuracia')
ax2.grid('on')
ax2.set_xlabel('Epocas')
ax2.set_ylabel('%')
ax2.set_ylim(top=1)
plt.savefig('CustoValidacaoADAMPytorch')
# Out:
# /home/victor/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
np.arange(10)

# %%
torch.save(modelo.state_dict(), 'CatDog')

# %% [markdown]
# ### Teste real

# %%
class DataTeste(Dataset):
    
    path = './animais/'
      
    tfms = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
    
    def __init__(self, x):
        self.x = x.copy()
        np.random.shuffle(self.x)
        
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, i):
        arq = self.x[i] 
        imagem = Image.open(self.path+arq).resize(2*(256,))
        return self.tfms(imagem)

# %%
import os

# %%
arqs = os.listdir('./animais/')

# %%
ds_real = DataTeste(arqs)

# %%
dl_real = DataLoader(ds_real, batch_size=1)

# %%
dl_iter = iter(dl_real)

# %%
x = next(dl_iter)

out = torch.sigmoid(modelo(x.to(device))).to('cpu').detach().numpy()

plt.imshow(x.squeeze().numpy().transpose(1,2,0))
plt.title(out)
plt.axis('off')
